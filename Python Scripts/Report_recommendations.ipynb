# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import time

# %%
items = pd.read_csv('C:/Users/Hassan Ali/Desktop/Data Mining Cup/items_cleaned.csv', encoding = 'latin-1')
transactions = pd.read_csv('C:/Users/Hassan Ali/Desktop/Data Mining Cup/transactions_cleaned.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
items[items['author']=="Shelley Admont, Kidkiddos Books"]
# Out:
#        itemID                                            title.x  \
# 576     34940  I Love My Dad Ich habe meinen Papa lieb: Engli...
# 1724    34464                   Let's play, Mom! (Greek edition)
# 6285    32962                I Love My Dad (Greek Book for Kids)
# 7630    61300       Goodnight, My Love! (Korean Children's Book)
# 8862    28566      Goodnight, My Love! (Tagalog Children's Book)
# ...       ...                                                ...
# 67238   38086             Amanda's Dream (Malay Children's Book)
# 67258   20708           I Love My Mom (Albanian Children's Book)
# 67334   61199     Goodnight, My Love! (Croatian Children's Book)
# 67340   26755  Sweet Dreams, My Love (Ukrainian Children's Book)
# 67441   23241  My Mom is Awesome (Punjabi Book for Kids- Gurm...
#
#                                 author             publisher main.topic  \
# 576    Shelley Admont, Kidkiddos Books   KIDKIDDOS BOOKS LTD        YFN
# ...

# %%
print(items.nunique())
# Out:
# itemID                     74039
# title.x                    72404
# author                     35723
# publisher                   7025
# main.topic                   692
# subtopics                  10647
# hug_article_id             67117
# title.y                    65680
# authors                    34165
# subtitle                   23341
# age_recommendation_from       20
# age_recommendation_to         42
# language                     125
# assortment                    18
# shortDescription           54050
# book_type                     10
# price                        758
# availability                 129
# description                54316
# isbn                       56178
# ean                        67038
# pages                        981
# cover_image_url            63820
# oldID                      74039
# dtype: int64

# %% [markdown]
# *itemID: 12152, 13382 (3448), 24603, 47675, 56180, 60644, 61261, 72826*

# %% [markdown]
# titles:
# White Rose
# Die Macht der Drei
# The Hobbit
# Cirkus Cannelloni i traditionens snara: Swedish Edition of Circus Cannelloni Invades Britain
# There it is! Da ist es!: A search and find book...
# Die Macht der Drei
# Die drei ??? Kids 45 - Ein Fall für Superhelde...
# Mandalas Weihnachten

# %%
items[items["itemID"]==72826]['title.x'].iloc[0]
# Out:
# 'Mandalas Weihnachten'

# %%
# find if an item ID is in the old IDs
id_num = "60644"
items[items["oldID"].str.find(id_num)>=0]
# Out:
#        itemID             title.x        author        publisher main.topic  \
# 62274    3448  Die Macht der Drei  Hans Dominik  Ganymed Edition         FL
#
#       subtopics  hug_article_id             title.y       authors subtitle  \
# 62274       NaN      26130273.0  Die Macht der Drei  Hans Dominik      NaN
#
#        ...                                   shortDescription  book_type  \
# 62274  ...  "Die Macht der Drei" ist ein technisch-wissens...        NaN
#
#       price                 availability  \
# 62274  0.99  Sofort lieferbar (Download)
#
#                                              description isbn           ean  \
# 62274  "Die Macht der Drei" ist ein technisch-wissens...  NaN  9.782322e+12
#
#        pages                                    cover_image_url  \
# 62274  362.0  https://media2.hugendubel.de/shop/coverscans/2...
#
#                                           oldID
# 62274  60644,13382,51370,39488,46822,50693,3448
#
# [1 rows x 24 columns]

# %%
items[items['title.x']=="Die Macht der Drei"]
# Out:
#        itemID             title.x        author        publisher main.topic  \
# 62274    3448  Die Macht der Drei  Hans Dominik  Ganymed Edition         FL
#
#       subtopics  hug_article_id             title.y       authors subtitle  \
# 62274       NaN      26130273.0  Die Macht der Drei  Hans Dominik      NaN
#
#        ...                                   shortDescription  book_type  \
# 62274  ...  "Die Macht der Drei" ist ein technisch-wissens...        NaN
#
#       price                 availability  \
# 62274  0.99  Sofort lieferbar (Download)
#
#                                              description isbn           ean  \
# 62274  "Die Macht der Drei" ist ein technisch-wissens...  NaN  9.782322e+12
#
#        pages                                    cover_image_url  \
# 62274  362.0  https://media2.hugendubel.de/shop/coverscans/2...
#
#                                           oldID
# 62274  60644,13382,51370,39488,46822,50693,3448
#
# [1 rows x 24 columns]

# %%
items[items['title.x']=="The Hobbit"]
# Out:
#       itemID     title.x                     author                 publisher  \
# 278    24603  The Hobbit  John Ronald Reuel Tolkien   Harper Collins Publ. UK
# 6622   11877  The Hobbit           J. R. R. Tolkien  HarperCollins Publishers
#
#      main.topic subtopics  hug_article_id     title.y  \
# 278          FM       NaN      20525432.0  The Hobbit
# 6622         FM       NaN       1684378.0  The Hobbit
#
#                         authors  \
# 278   John Ronald Reuel Tolkien
# 6622           J. R. R. Tolkien
#
#                                                subtitle  ...  \
# 278   200 colour illustrations. \r\r\nSprache: Engli...  ...
# 6622  Empfohlen von 12 bis 17 Jahren. \r\r\nNone. \r...  ...
#
#                                        shortDescription  book_type  price  \
# 278   Contains over 150 brand new illustrations for ...        NaN  25.49
# 6622  Featuring stunning new cover art by Caldecott ...        NaN  11.49
#
# ...

# %% [markdown]
# *LDA (#2,3,6,7,8)*

# %%
# descriptions
print(list(items[items["itemID"]==3448]["description"])) 
print("\n")
print(list(items[items["itemID"]==24603]["description"]))
print("\n")
print(list(items[items["itemID"]==61261]["description"]))
print("\n")
print(list(items[items["itemID"]==72826]["description"]))
# Out:
# ['"Die Macht der Drei" ist ein technisch-wissenschaftlicher Zukunftsroman von Hans Dominik.\r Nach einem Vorabdruck in der Zeitschrift "Die Woche" in 26 Teilen (3. Dezember 1921 bis 27. Mai 1922) erschien der Roman 1922 beim Scherl-Verlag (Berlin) erstmals in Buchform. Hans Dominik schrieb das Buch in nur sechs Monaten.\r "Die Macht der Drei" stellt eine abgeschlossene Geschichte dar; "Atlantis" kann allerdings als Nachfolgeroman gelesen werden.']
#
#
# ['A new edition of the classic work of fantasy, with 150 new illustrations specifically designed for children, but which can be also enjoyed by adults. Illustrated by Jemima Catlin, and published before the 2nd "Hobbit" film, "The Desolation Of Smaug".']
#
#
# ['Erzählt von Ulf Blanck']
#
#
# ...

# %%
lda = pd.read_csv('C:/Users/Hassan Ali/Desktop/Data Mining Cup/Final csv files/LDA_average.csv',low_memory = False)
lda = lda.drop('Unnamed: 0',axis=1)

# %%
list(items[items['title.x']=='One of Us is Lying']['description'])
# Out:
# ["THE INTERNATIONAL BESTSELLERFive students go to detention. Only four leave alive.Yale hopeful Bronwyn has never publicly broken a rule.Sports star Cooper only knows what he's doing in the baseball diamond.Bad boy Nate is one misstep away from a life of crime.Prom queen Addy is holding together the cracks in her perfect life.And outsider Simon, creator of the notorious gossip app at Bayview High, won't ever talk about any of them again.He dies 24 hours before he could post their deepest secrets online. Investigators conclude it's no accident. All of them are suspects.Everyone has secrets, right?What really matters is how far you'll go to protect them.'Tightly plotted and brilliantly written, with sharp, believable characters, this whodunit is utterly irresistible' - HEAT 'Twisty plotting, breakneck pacing and intriguing characterisation add up to an exciting single-sitting thrillerish treat' -THE GUARDIAN'A fantastic murder mystery, packed with cryptic clues and countless plot twist
# ...

# %%
item_id =  61261      # 3448, 24603, 61261, 72826
print(item_id)
df = lda[lda['from']==item_id]
df.sort_values(by='score', ascending=False, inplace=True)

print(list(items[items['itemID']==item_id]['title.x']))
print(list(items[items['itemID']==item_id]['main.topic']), "\n\n")

l = df ['to'].values.tolist ()
g = df ['score'].values.tolist ()
for i in range(0,20):
    print(list(items[items['itemID'] == l[i]]['title.x']),g[i])
    print(list(items[items['itemID'] == l[i]]['description']),"\n")
# Out:
# 61261
# ['Die drei ??? Kids 45 - Ein Fall fÃ¼r Superhelden (drei Fragezeichen)']
# ['YFCF']
#
#
# ['Die drei ??? Kids 46 - Jagd auf das Dino-Ei (drei Fragezeichen)'] 0.9999996171144784
# ['Erzählt von Ulf Blanck']
#
# ['Die Ameisenkolonie'] 0.9015431229904224
# ['Die Geschichte eines Ausreißers']
#
# ['Der unheilige Gral'] 0.7983164763051925
# ['Ein Klassiker der Fantasyliteratur!']
#
# ['Der kleine Hobbit Veredelte Mini-Ausgabe'] 0.7983159470013741
# ['Der Klassiker']
#
# ['Der kleine Hobbit Normalformat'] 0.7983157639657965
# ['Der Klassiker']
#
# ['WH40K Wrath & Glory Finstere Segnungen'] 0.7929319183094166
# ['Finstere Segnungen']
#
# ['Wir beide wussten, es war was passiert'] 0.7916272927195617
# ['selbstsicher zu erscheinen. ']
#
# ['Der geheime Zirkel 02. Circes RÃ¼ckkehr'] 0.7904538867670734
# ['Circes Rückkehr']
#
# ['Die Karlsson-Kinder 02. Wombats und wilde Kerle'] 0.784985653627591
# ['Endlich sind die Karlssons wieder da!']
#
# ['Das Angstexperiment'] 0.7829739293229361
# ...

# %%
# insert name to view description
name = 'City of Ashes'
list(items[items["title.x"]==name]['description'])
# Out:
# ['In this breathtaking sequel to "City of Bones," Cassandra Clare lures her readers back into the dark grip of New York City\'s Downworld, where love is never safe and power becomes the deadliest temptation.Margaret K. McElderry Books']

# %% [markdown]
# *fall back (#1,4,5)*

# %%
items[items['itemID']==12152]
# Out:
#        itemID     title.x      author  \
# 58086   12152  White Rose  Kip Wilson
#
#                                           publisher main.topic subtopics  \
# 58086  Houghton Mifflin Harcourt Publishing Company        YFB       NaN
#
#        hug_article_id title.y authors subtitle  ...  shortDescription  \
# 58086             NaN     NaN     NaN      NaN  ...               NaN
#
#        book_type price availability description isbn  ean pages  \
# 58086        NaN   NaN          NaN         NaN  NaN  NaN   NaN
#
#       cover_image_url  oldID
# 58086             NaN  12152
#
# [1 rows x 24 columns]

# %%
print(items[items['main.topic']=="YFQ"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                            title.x & main.topic \\
# \midrule
#                                    The Gossip File &        YFQ \\
#  Hiram Ulysses Aloysius Higgenbotham's Special Day &        YFQ \\
#  Cake for Breakfast Every Day - English/German ... &        YFQ \\
#                                        In My Attic &        YFQ \\
#  There Was an Old Lady Who Swallowed a Bell! [W... &        YFQ \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==47675]
# Out:
#        itemID                                            title.x      author  \
# 59754   47675  Cirkus Cannelloni i traditionens snara: Swedis...  Tuula Pere
#
#           publisher main.topic subtopics  hug_article_id title.y authors  \
# 59754  WICKWICK LTD        YFQ       NaN             NaN     NaN     NaN
#
#       subtitle  ...  shortDescription  book_type price availability  \
# 59754      NaN  ...               NaN        NaN   NaN          NaN
#
#       description isbn  ean pages cover_image_url  oldID
# 59754         NaN  NaN  NaN   NaN             NaN  47675
#
# [1 rows x 24 columns]

# %%
items[items['main.topic']=="YFQ"].sample(n=5)
# Out:
#        itemID                                       title.x  \
# 35666    8415                     Diary of a Tennis Prodigy
# 69473   72431                               Super Organized
# 63593   43318  Grace and the Band Class That Never Happened
# 44155   24394                                      Millions
# 31756   54263                    Fennymore and the Brumella
#
#                                  author             publisher main.topic  \
# 35666                     Shamini Flint         ALLEN & UNWIN        YFQ
# 69473      Michael Christopher Alderson              BOOKBABY        YFQ
# 63593  Grace Elaine, Sametria Alexander  WILSON LEARNING CORP        YFQ
# 44155              Frank Cottrell Boyce         HARPERCOLLINS        YFQ
# 31756                 Kirsten Reinhardt         Little Island        YFQ
#
#       subtopics  hug_article_id                                       title.y  \
# 35666       YFR      25154951.0                     Diary of a Tennis Prodigy
# ...

# %%
items[items['itemID']==56180]
# Out:
#        itemID                                            title.x  \
# 68023   56180  There it is! Da ist es!: A search and find boo...
#
#                      author      publisher main.topic subtopics  \
# 68023  Marta Almansa Esteva  THE LIFFEY PR       YBLD       NaN
#
#        hug_article_id                                            title.y  \
# 68023      40278797.0  There it is! Da ist es!: A search and find boo...
#
#                     authors            subtitle  ...  shortDescription  \
# 68023  Marta Almansa Esteva  Sprache: Englisch.  ...               NaN
#
#        book_type  price   availability description          isbn  \
# 68023        NaN  12.49  vorbestellbar         NaN  1.838354e+09
#
#                 ean pages                                    cover_image_url  \
# 68023  9.781838e+12  42.0  https://media2.hugendubel.de/shop/coverscans/4...
#
#        oldID
# 68023  56180
#
# [1 rows x 24 columns]

# %%
items[items['main.topic']=="YBLD"].sample(n=5)
# Out:
#        itemID                         title.x           author  \
# 687     39716               Das Farbenmonster      Anna Llenas
# 43462    7883            Crayola: Holi Colors     Robin Nelson
# 46529   15916  How To Make Slime The Fun Way!  Natalie Fleming
# 73608   30467                   Color My Soul      A. Phillips
# 27402   33856   Learning to Color with Rhymes   Burdys D. Page
#
#              publisher main.topic         subtopics  hug_article_id  \
# 687      Velber Verlag       YBLD  5AC,YBLD,YNN,YXE      31138122.0
# 43462      LERNER PUBN       YBLD     5HP,YNMD,YNRD      31541023.0
# 46529  Stephen Fleming       YBLD               NaN      33732062.0
# 73608          Xlibris       YBLD               NaN       9113371.0
# 27402   Sunstone Press       YBLD               NaN      19073229.0
#
#                               title.y          authors  \
# 687                 Das Farbenmonster      Anna Llenas
# 43462            Crayola: Holi Colors     Robin Nelson
# ...

# %% [markdown]
# *Same Author and Publisher*

# %%
items[items['itemID']==12152]
# Out:
#        itemID     title.x      author  \
# 58086   12152  White Rose  Kip Wilson
#
#                                           publisher main.topic subtopics  \
# 58086  Houghton Mifflin Harcourt Publishing Company        YFB       NaN
#
#        hug_article_id title.y authors subtitle  ...  shortDescription  \
# 58086             NaN     NaN     NaN      NaN  ...               NaN
#
#        book_type price availability description isbn  ean pages  \
# 58086        NaN   NaN          NaN         NaN  NaN  NaN   NaN
#
#       cover_image_url  oldID
# 58086             NaN  12152
#
# [1 rows x 24 columns]

# %%
# no other books by the same author
print(items[items['publisher']=="Houghton Mifflin Harcourt Publishing Company"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                  title.x & main.topic \\
# \midrule
#         Girl Named Digit &       YFCF \\
#  Last Last-Day-Of-Summer &       YBLJ \\
#                Mechanica &        YFH \\
#       How to Make a Wish &        YFB \\
#                   Awaken &        YFH \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==3448]
# Out:
#        itemID             title.x        author        publisher main.topic  \
# 62274    3448  Die Macht der Drei  Hans Dominik  Ganymed Edition         FL
#
#       subtopics  hug_article_id             title.y       authors subtitle  \
# 62274       NaN      26130273.0  Die Macht der Drei  Hans Dominik      NaN
#
#        ...                                   shortDescription  book_type  \
# 62274  ...  "Die Macht der Drei" ist ein technisch-wissens...        NaN
#
#       price                 availability  \
# 62274  0.99  Sofort lieferbar (Download)
#
#                                              description isbn           ean  \
# 62274  "Die Macht der Drei" ist ein technisch-wissens...  NaN  9.782322e+12
#
#        pages                                    cover_image_url  \
# 62274  362.0  https://media2.hugendubel.de/shop/coverscans/2...
#
#                                           oldID
# 62274  60644,13382,51370,39488,46822,50693,3448
#
# [1 rows x 24 columns]

# %%
print(items[items['author']=="Hans Dominik"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                    title.x & main.topic \\
# \midrule
#  Land aus Feuer und Wasser &         FL \\
#               Himmelskraft &         FL \\
#      Das Erbe der Uraniden &         FL \\
#      Befehl aus dem Dunkel &         FL \\
#   Das stÃ¤hlerne Geheimnis &         FL \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==24603]
# Out:
#      itemID     title.x                     author                publisher  \
# 278   24603  The Hobbit  John Ronald Reuel Tolkien  Harper Collins Publ. UK
#
#     main.topic subtopics  hug_article_id     title.y  \
# 278         FM       NaN      20525432.0  The Hobbit
#
#                        authors  \
# 278  John Ronald Reuel Tolkien
#
#                                               subtitle  ...  \
# 278  200 colour illustrations. \r\r\nSprache: Engli...  ...
#
#                                       shortDescription  book_type  price  \
# 278  Contains over 150 brand new illustrations for ...        NaN  25.49
#
#       availability                                        description  \
# 278  vorbestellbar  A new edition of the classic work of fantasy, ...
#
#           isbn           ean  pages  \
# 278  7497903.0  9.780007e+12  320.0
#
#                                        cover_image_url  oldID
# 278  https://media2.hugendubel.de/shop/coverscans/2...  24603
#
# ...

# %%
print(items[items['author']=="John Ronald Reuel Tolkien"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                      title.x & main.topic \\
# \midrule
#                The Colour Illustrated Hobbit &         FM \\
#                           Die Kinder HÃºrins &        FMB \\
#  The Pocket Hobbit. 75th Anniversary Edition &        FBC \\
#                Letters from Father Christmas &        YFH \\
#                        The Lord of the Rings &         FM \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==47675]
# Out:
#        itemID                                            title.x      author  \
# 59754   47675  Cirkus Cannelloni i traditionens snara: Swedis...  Tuula Pere
#
#           publisher main.topic subtopics  hug_article_id title.y authors  \
# 59754  WICKWICK LTD        YFQ       NaN             NaN     NaN     NaN
#
#       subtitle  ...  shortDescription  book_type price availability  \
# 59754      NaN  ...               NaN        NaN   NaN          NaN
#
#       description isbn  ean pages cover_image_url  oldID
# 59754         NaN  NaN  NaN   NaN             NaN  47675
#
# [1 rows x 24 columns]

# %%
# all books by this author are from the same publisher
print(items[items['author']=="Tuula Pere"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                            title.x & main.topic \\
# \midrule
#  Macja ShÃ«ruese: Albanian Edition of The Heale... &        YFC \\
#                           Leo, the Little Wanderer &        YFB \\
#  Et Medicus Cattus: Latin Edition of The Healer... &        YFC \\
#                                Den helbredende kat &     YNNJ22 \\
#                         Kaj Krabba finner en skatt &       YNNS \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==56180]
# Out:
#        itemID                                            title.x  \
# 68023   56180  There it is! Da ist es!: A search and find boo...
#
#                      author      publisher main.topic subtopics  \
# 68023  Marta Almansa Esteva  THE LIFFEY PR       YBLD       NaN
#
#        hug_article_id                                            title.y  \
# 68023      40278797.0  There it is! Da ist es!: A search and find boo...
#
#                     authors            subtitle  ...  shortDescription  \
# 68023  Marta Almansa Esteva  Sprache: Englisch.  ...               NaN
#
#        book_type  price   availability description          isbn  \
# 68023        NaN  12.49  vorbestellbar         NaN  1.838354e+09
#
#                 ean pages                                    cover_image_url  \
# 68023  9.781838e+12  42.0  https://media2.hugendubel.de/shop/coverscans/4...
#
#        oldID
# 68023  56180
#
# [1 rows x 24 columns]

# %%
# only one book by this author and publisher
print(items[items['publisher']=="THE LIFFEY PR"][['title.x','main.topic']].to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                            title.x & main.topic \\
# \midrule
#  There it is! Da ist es!: A search and find boo... &       YBLD \\
# \bottomrule
# \end{tabular}

# %%
items[items['itemID']==61261]
# Out:
#        itemID                                            title.x      author  \
# 14946   61261  Die drei ??? Kids 45 - Ein Fall fÃ¼r Superheld...  Ulf Blanck
#
#                      publisher main.topic             subtopics  \
# 14946  dtv Verlagsgesellschaft       YFCF  5AJ,1KBB-US-WPC,YXHB
#
#        hug_article_id                                            title.y  \
# 14946      27988140.0  Die drei ??? Kids 45 - Ein Fall für Superhelde...
#
#           authors                                           subtitle  ...  \
# 14946  Ulf Blanck  Empfohlen von 7 bis 11 Jahren. \r\r\nMit Illus...  ...
#
#                    shortDescription  book_type price      availability  \
# 14946  Es geht weiter für das Trio!        NaN  5.95  Sofort lieferbar
#
#                   description          isbn           ean  pages  \
# 14946  Erzählt von Ulf Blanck  3.423717e+09  9.783424e+12  123.0
#
#                                          cover_image_url  oldID
# ...

# %%
print(items[items['author']=="Ulf Blanck"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
# Out:
# \begin{tabular}{ll}
# \toprule
#                                            title.x & main.topic \\
# \midrule
#  Die drei ??? Kids 24: Im Bann des Zauberers (d... &       YFCF \\
#  Die drei ??? Kids 46 - Jagd auf das Dino-Ei (d... &       YFCF \\
#             Die drei ??? Kids 18: Mission Maulwurf &       YFCF \\
#  Die drei ??? Kids 45 - Ein Fall fÃ¼r Superheld... &       YFCF \\
#  Die drei ??? Kids 60: Gespensterjagd (drei Fra... &       YFCF \\
# \bottomrule
# \end{tabular}

# %%
items[items['author']=="Ulf Blanck"]['title.x'].iloc[0]
# Out:
# 'Die drei out Kids und du: Labyrinth der Piraten'

# %%
items[items['itemID']==72826]
# Out:
#        itemID               title.x         author        publisher  \
# 71646   72826  Mandalas Weihnachten  Andreas Abato  Books on Demand
#
#       main.topic subtopics  hug_article_id               title.y  \
# 71646        YFB       NaN       6956295.0  Mandalas Weihnachten
#
#              authors                                           subtitle  ...  \
# 71646  Andreas Abato  Wunderschöne weihnachtliche Mandalas zum Ausma...  ...
#
#                                         shortDescription  book_type price  \
# 71646  Wunderschöne weihnachtliche Motive zum Ausmale...        NaN   9.8
#
#            availability                                        description  \
# 71646  Sofort lieferbar  Wunderschöne weihnachtliche Motive zum Ausmale...
#
#                isbn           ean pages  \
# 71646  3.833492e+09  9.783833e+12  52.0
#
#                                          cover_image_url  oldID
# 71646  https://media2.hugendubel.de/shop/coverscans/6...  72826
#
# ...

# %%
print(items[items['author']=="Andreas Abato"][['title.x','main.topic']].sample(n=5).to_latex(index=False))
items[items['author']=="a"][['title.x','main.topic', 'description']]
# Out:
# \begin{tabular}{ll}
# \toprule
#                                            title.x & main.topic \\
# \midrule
#                        Mandalas Liebe Rosen Herzen &        YFB \\
#  Meine Mandalas - Mein Ausmalbuch - WunderschÃ¶... &       YNPH \\
#  Meine Mandalas - Spass am Ausmalen - Wundersch... &       YNPH \\
#                                     Mandalas Autos &       YNPH \\
#  Meine Mandalas - Mit Freude Ausmalen - Wunders... &       YNPH \\
# \bottomrule
# \end{tabular}
#                                                  title.x main.topic  \
# 8829   Meine Mandalas - Mein Ausmalbuch - WunderschÃ¶...       YNPH
# 12530  Meine Mandalas - Meine schÃ¶nsten Muster - Wun...       YNPH
# 16227                Die schÃ¶nsten Mandalas fÃ¼r Kinder       YNPH
# 17456  Meine Mandalas - FÃ¼r coole Kids - WunderschÃ¶...       YNPH
# 18900  Meine Mandalas - Mein cooles Ausmalbuch - Wund...       YNPH
# 19345  Meine Mandalas - Cool und kreativ - WunderschÃ...       YNPH
# ...

# %%
list(items[items['author']=="Andreas Abato"][['title.x','main.topic']].iloc[5])
# Out:
# ['Meine Mandalas - Cool und kreativ - WunderschÃ¶ne Mandalas zum Ausmalen',
#  'YNPH']

# %% [markdown]
# *Most Frequently Ordered of the same Category*

# %%
transactions[transactions['order']>0][['itemID','order']].groupby('itemID').sum().sort_values('order', ascending=False)
# Out:
#         order
# itemID
# 53695     170
# 69803     125
# 47120     122
# 31591      95
# 45799      93
# 13711      93
# 78643      91
# 19379      90
# 74398      84
# 55215      83
# 23654      73
# 40692      70
# 52146      66
# 32539      66
# 55699      65
# 77471      59
# 14526      58
# 58522      56
# 42556      54
# 8960       49
# 26448      48
# 3259       48
# 64239      46
# 61335      46
# 15840      45
# 50816      45
# 46860      44
# 34815      43
# 35696      43
# 33862      43
# 59411      41
# 19458      40
# 63730      40
# 42353      39
# 74565      38
# 71270      37
# 48856      37
# 62556      37
# 39716      36
# 886        36
# 14207      35
# 69185      35
# 31955      34
# 60430      34
# 57800      34
# 36098      33
# 1607       33
# 20936      33
# 54531      33
# 36071      33
# 4626       33
# 44220      31
# 30734      31
# 42836      31
# 69073      30
# 27714      30
# 20641      29
# 18824      29
# 59360      29
# 57111      29
# ...

# %%
df = transactions[transactions['order']>0][['itemID','order']].groupby('itemID').sum().sort_values('order', ascending=False)

# %%
df_new = items[items["itemID"].isin(df.index)]
df_new = df_new.set_index('itemID')
df_new = df_new.reindex(df.index)
df_new['orders'] = pd.Series(df['order'])
df_new['title.x'].iloc[0]
# Out:
# 'Rico, Oskar und die Tieferschatten (Rico und Oskar 1)'

# %% [markdown]
# main topics for the 8 item IDs: YFB, FL, FM, YFQ, YBLD, FL, YFCF, YFB

# %%
print(df_new[['title.x','main.topic','orders']][df_new['main.topic']=="YFCF"].iloc[0:5].to_latex(index=False))
# Out:
# \begin{tabular}{llr}
# \toprule
#                                            title.x & main.topic &  orders \\
#  Rico, Oskar und die Tieferschatten (Rico und O... &       YFCF &     170 \\
# \midrule
#                      Level 4. Die Stadt der Kinder &       YFCF &      37 \\
#                                 One of Us is Lying &       YFCF &      27 \\
#                              BeschÃ¼tzer der Diebe &       YFCF &      25 \\
#  Oskar und das Geheimnis der verschwundenen Kinder &       YFCF &      14 \\
# \bottomrule
# \end{tabular}

# %%
df_new['title.x'][df_new['main.topic']=="FM"].iloc[2]
# Out:
# 'Das Lied von Eis und Feuer 01. Die Herren von Winterfell'

# %%
list(items[items["title.x"]=="The Invisible Life of Addie LaRue"]['description'])
# Out:
# ["In the vein of The Time Traveler's Wife and Life After Life, The Invisible Life of Addie LaRue is New York Times bestselling author V. E. Schwab's genre-defying tour de force.When Addie La Rue makes a pact with the devil, she trades her soul for immortality. But there's always a price - the devil takes away her place in the world, cursing her to be forgotten by everyone.Addie flees her tiny home town in 18th-Century France, beginning a journey that takes her across the world, learning to live a life where no one remembers her and everything she owns is lost and broken. Existing only as a muse for artists throughout history, she learns to fall in love anew every single day.Her only companion on this journey is her dark devil with hypnotic green eyes, who visits her each year on the anniversary of their deal. Alone in the world, Addie has no choice but to confront him, to understand him, maybe to beat him.Until one day, in a second hand bookshop in Manhattan, Addie meets someone who 
# ...
