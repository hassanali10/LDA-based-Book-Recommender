# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
import time

# %%
items = pd.read_csv('C:/Users/Hassan Ali/Desktop/Data Mining Cup/items_cleaned.csv', encoding = 'latin-1')

# %%
pd.set_option('display.max_rows', 500)

# %%
items[items['title.x']=="The Hate U Give"]['language']
# Out:
# 1464    german
# Name: language, dtype: object

# %%
items.groupby('language')['itemID'].nunique().sort_values(ascending=False).reset_index(name='count')
# Out:
#                      language  count
# 0                    Englisch  41943
# 1                      german  27290
# 2                    Spanisch   1495
# 3                 Französisch    798
# 4                 Italienisch    737
# 5               Portugiesisch    287
# 6                  Schwedisch    146
# 7              Niederländisch    139
# 8                    Russisch    138
# 9                   Walisisch     70
# 10               Mehrsprachig     55
# 11                   Finnisch     55
# 12                  Ungarisch     52
# 13                  Malayalam     49
# 14                      Hindi     47
# 15                  Rumänisch     40
# 16                    Dänisch     38
# 17                 Norwegisch     36
# 18                 Chinesisch     35
# 19                   Türkisch     30
# 20                 Griechisch     24
# 21                Katalanisch     24
# 22                  Afrikaans     24
# 23                   Arabisch     23
# ...

# %%
my_data = [56.6,36.9,2.0,1.1,1.0,0.4,2.0]
my_labels = ['English','German','Spanish','French','Italian','Portuguese','Other']
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.title('My Title')
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(7,4))
my_data = [56.6,36.9,2.0,4.5]
my_labels = ['English','German','Spanish','Other']
plt.pie(my_data,labels=my_labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()
fig.savefig('d1.jpg', bbox_inches='tight', dpi=1000)
